# %%
from kmeans import *
# %matplotlib inline

# %%
X = generate_data_2D(3)

# %%
model = kmeans(k=3, random_seed=42)
model.fit(X)

# %%
model.plot()

# %%
X_new = generate_data_2D(4)
model.plot(X_new = X_new)
